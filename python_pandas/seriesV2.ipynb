# %% [markdown]
# <a href="https://colab.research.google.com/github/guzik1234/DataScienceCwiczenia/blob/main/python_pandas/seriesV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#generowanie danych
#ziarno losowe
np.random.seed(0)

A = np.random.randint(0, 10, 10)
A
# Out:
# array([5, 0, 3, 3, 7, 9, 3, 5, 2, 4])

# %%
series = pd.Series(A, name='los')
series
# Out:
# 0    5
# 1    0
# 2    3
# 3    3
# 4    7
# 5    9
# 6    3
# 7    5
# 8    2
# 9    4
# Name: los, dtype: int64

# %%
#jaki typ zmiennych zawiera typu series
series.dtype
series.iloc[3]
# Out:
# np.int64(3)

# %%
series.iloc[-1]
# Out:
# np.int64(4)

# %%
series.index
#jaki rodzaj indeksu to jest
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
series.name
# Out:
# 'los'

# %%
series.shape
# Out:
# (10,)

# %%
#zamiana na zwykla tablice
array_A = series.values
array_A
# Out:
# array([5, 0, 3, 3, 7, 9, 3, 5, 2, 4])

# %%
N = np.random.randn(10)
M = np.random.randn(10)

# %%
series_N = pd.Series(N)
series_M = pd.Series(M)

# %%
series_N.abs()
series_N.add(series_M)
# Out:
# 0    0.136979
# 1   -0.256553
# 2    1.241308
# 3   -1.885702
# 4    1.920484
# 5    1.596766
# 6    1.730208
# 7    1.268164
# 8    2.815169
# 9   -1.109061
# dtype: float64

# %%
series_N.subtract(series_M)
series_N.divide(series_M)
# Out:
# 0    -0.680234
# 1     1.077976
# 2    -0.122365
# 3    14.201066
# 4    -0.043658
# 5     5.945887
# 6     1.860350
# 7    -0.220627
# 8     0.765482
# 9    -5.812921
# dtype: float64

# %%
series.drop_duplicates()
series
# Out:
# 0    5
# 1    0
# 2    3
# 3    3
# 4    7
# 5    9
# 6    3
# 7    5
# 8    2
# 9    4
# Name: los, dtype: int64

# %%
series[4] = np.nan # ustawienie danej wartosci na nan

# %%
series
# Out:
# 0    5.0
# 1    0.0
# 2    3.0
# 3    3.0
# 4    NaN
# 5    9.0
# 6    3.0
# 7    5.0
# 8    2.0
# 9    4.0
# Name: los, dtype: float64

# %%
series.dropna() # pomijanie wartosci pustych
# Out:
# 0    5.0
# 1    0.0
# 2    3.0
# 3    3.0
# 5    9.0
# 6    3.0
# 7    5.0
# 8    2.0
# 9    4.0
# Name: los, dtype: float64

# %%
# Out:
# 5

# %%
series.idxmin()
# Out:
# 1

# %%
series.count() #zliczanie ilosci elementow
# Out:
# np.int64(9)

# %%
series_N.cumsum() # liczy sume wartosci wszystkich elementow
# Out:
# 0   -0.291394
# 1   -0.424484
# 2   -0.597554
# 3   -2.359206
# 4   -2.446879
# 5   -1.079999
# 6    0.045315
# 7   -0.313681
# 8    0.906927
# 9   -0.432568
# dtype: float64

# %%
series_N.cummin() # namniejsze wartosci w czasie
# Out:
# 0   -0.291394
# 1   -0.291394
# 2   -0.291394
# 3   -1.761652
# 4   -1.761652
# 5   -1.761652
# 6   -1.761652
# 7   -1.761652
# 8   -1.761652
# 9   -1.761652
# dtype: float64

# %%
series_N.cummax() # najwikesze wartosci w czasie
# Out:
# 0   -0.291394
# 1   -0.133090
# 2   -0.133090
# 3   -0.133090
# 4   -0.087673
# 5    1.366879
# 6    1.366879
# 7    1.366879
# 8    1.366879
# 9    1.366879
# dtype: float64

# %%
series.value_counts() # ile razy dany element wystepowal
# Out:
# los
# 3.0    3
# 5.0    2
# 0.0    1
# 9.0    1
# 2.0    1
# 4.0    1
# Name: count, dtype: int64

# %%
series.sum()
# Out:
# np.float64(34.0)

# %%
series.std() #odchylenie standardowe
# Out:
# 2.4888640871780128

# %%
series.describe()
# Out:
# count    9.000000
# mean     3.777778
# std      2.488864
# min      0.000000
# 25%      3.000000
# 50%      3.000000
# 75%      5.000000
# max      9.000000
# Name: los, dtype: float64

# %%
hist_data = pd.Series(np.random.randn(10000))
hist_data.hist(bins=80, color='green')
# Out:
# <Axes: >

# %%
#top najwieksze wartosci n
top_3 = series.nlargest(3)
top_3
# Out:
# 5    9.0
# 0    5.0
# 7    5.0
# Name: los, dtype: float64

# %%
bottom_4 = series_N.nsmallest(4)
bottom_4
# Out:
# 3   -1.761652
# 9   -1.339496
# 7   -0.358996
# 0   -0.291394
# dtype: float64

# %%
# kwartyle
q_1 = series_N.quantile(0.25)
q_2 = series_N.quantile(0.5)

# %%
series_N.round(3)
# Out:
# 0   -0.291
# 1   -0.133
# 2   -0.173
# 3   -1.762
# 4   -0.088
# 5    1.367
# 6    1.125
# 7   -0.359
# 8    1.221
# 9   -1.339
# dtype: float64

# %%
shift_1 = series.shift(1) #przesuwa o 1 wiersz do dolu
shift_2_replace_0 = series.shift(2).fillna(0)
shift_2_replace_0
# Out:
# 0    0.0
# 1    0.0
# 2    5.0
# 3    0.0
# 4    3.0
# 5    3.0
# 6    0.0
# 7    9.0
# 8    3.0
# 9    5.0
# Name: los, dtype: float64

# %%
sorted_series = series.sort_values()
sorted_series = series.sort_values(ascending=False)
sorted_series
# Out:
# 5    9.0
# 0    5.0
# 7    5.0
# 9    4.0
# 2    3.0
# 6    3.0
# 3    3.0
# 8    2.0
# 1    0.0
# 4    NaN
# Name: los, dtype: float64
