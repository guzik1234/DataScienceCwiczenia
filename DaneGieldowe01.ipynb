# %% [markdown]
# <a href="https://colab.research.google.com/github/guzik1234/DataScienceCwiczenia/blob/main/DaneGieldowe01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

print(f'Numpy version: {np.__version__}')
print(f'Pandas version: {pd.__version__}')
# Out:
# Numpy version: 2.0.2
# Pandas version: 2.2.2

# %%
def fetch_financial_data(company='AMZN'):
    """
    pobiera dane doyczace notowan sposlek na gieldzie wedlug symboli na serwisie stooq.pl
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1255 entries, 2025-10-06 to 2020-10-07
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1255 non-null   float64
#  1   High    1255 non-null   float64
#  2   Low     1255 non-null   float64
#  3   Close   1255 non-null   float64
#  4   Volume  1255 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.8 KB

# %%
df
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2025-10-06  221.000  221.730  216.030  220.900   42481401
# 2025-10-03  223.440  224.200  219.340  219.510   43639033
# 2025-10-02  221.010  222.810  218.945  222.410   41258586
# 2025-10-01  217.360  222.150  216.610  220.630   43933834
# 2025-09-30  222.030  222.240  217.890  219.570   48396369
# ...             ...      ...      ...      ...        ...
# 2020-10-13  173.400  174.619  171.211  172.182  114893940
# 2020-10-12  167.497  174.812  166.978  172.146  167283960
# 2020-10-09  160.500  164.450  159.892  164.332   98157420
# 2020-10-08  161.249  161.665  158.749  159.528   63482280
# 2020-10-07  156.750  160.000  156.619  159.784   86188780
#
# [1255 rows x 5 columns]

# %%
df.head(3)
# Out:
#               Open    High      Low   Close    Volume
# Date
# 2025-10-06  221.00  221.73  216.030  220.90  42481401
# 2025-10-03  223.44  224.20  219.340  219.51  43639033
# 2025-10-02  221.01  222.81  218.945  222.41  41258586

# %%
df.tail(4)
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2020-10-12  167.497  174.812  166.978  172.146  167283960
# 2020-10-09  160.500  164.450  159.892  164.332   98157420
# 2020-10-08  161.249  161.665  158.749  159.528   63482280
# 2020-10-07  156.750  160.000  156.619  159.784   86188780

# %%
df.tail()
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2020-10-13  173.400  174.619  171.211  172.182  114893940
# 2020-10-12  167.497  174.812  166.978  172.146  167283960
# 2020-10-09  160.500  164.450  159.892  164.332   98157420
# 2020-10-08  161.249  161.665  158.749  159.528   63482280
# 2020-10-07  156.750  160.000  156.619  159.784   86188780

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.columns = [col.lower() for col in df.columns]
df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
df.head()
# Out:
#               open    high      low   close    volume
# Date
# 2025-10-06  221.00  221.73  216.030  220.90  42481401
# 2025-10-03  223.44  224.20  219.340  219.51  43639033
# 2025-10-02  221.01  222.81  218.945  222.41  41258586
# 2025-10-01  217.36  222.15  216.610  220.63  43933834
# 2025-09-30  222.03  222.24  217.890  219.57  48396369

# %%
df.describe()
# Out:
#               open         high          low        close        volume
# count  1255.000000  1255.000000  1255.000000  1255.000000  1.255000e+03
# mean    160.115614   162.003025   158.075778   160.074284  5.969599e+07
# std      37.525275    37.630612    37.316004    37.498030  2.812643e+07
# min      82.800000    83.480000    81.430000    81.820000  1.500750e+07
# 25%     132.055000   133.630000   130.462500   132.025000  4.113486e+07
# 50%     162.800000   164.583000   160.985000   162.846000  5.355354e+07
# 75%     183.235000   185.215000   180.983000   183.430000  7.070851e+07
# max     239.015000   242.520000   238.030000   242.060000  2.726617e+08

# %%
df.describe().T
# Out:
#          count          mean           std          min           25%  \
# open    1255.0  1.601156e+02  3.752528e+01        82.80  1.320550e+02
# high    1255.0  1.620030e+02  3.763061e+01        83.48  1.336300e+02
# low     1255.0  1.580758e+02  3.731600e+01        81.43  1.304625e+02
# close   1255.0  1.600743e+02  3.749803e+01        81.82  1.320250e+02
# volume  1255.0  5.969599e+07  2.812643e+07  15007497.00  4.113486e+07
#
#                  50%           75%           max
# open    1.628000e+02  1.832350e+02  2.390150e+02
# high    1.645830e+02  1.852150e+02  2.425200e+02
# low     1.609850e+02  1.809830e+02  2.380300e+02
# close   1.628460e+02  1.834300e+02  2.420600e+02
# volume  5.355354e+07  7.070851e+07  2.726617e+08

# %%
df['open']
# Out:
# Date
# 2025-10-06    221.000
# 2025-10-03    223.440
# 2025-10-02    221.010
# 2025-10-01    217.360
# 2025-09-30    222.030
#                ...
# 2020-10-13    173.400
# 2020-10-12    167.497
# 2020-10-09    160.500
# 2020-10-08    161.249
# 2020-10-07    156.750
# Name: open, Length: 1255, dtype: float64

# %%
df.open
# Out:
# Date
# 2025-10-06    221.000
# 2025-10-03    223.440
# 2025-10-02    221.010
# 2025-10-01    217.360
# 2025-09-30    222.030
#                ...
# 2020-10-13    173.400
# 2020-10-12    167.497
# 2020-10-09    160.500
# 2020-10-08    161.249
# 2020-10-07    156.750
# Name: open, Length: 1255, dtype: float64

# %%
df[['open']]
# Out:
#                open
# Date
# 2025-10-06  221.000
# 2025-10-03  223.440
# 2025-10-02  221.010
# 2025-10-01  217.360
# 2025-09-30  222.030
# ...             ...
# 2020-10-13  173.400
# 2020-10-12  167.497
# 2020-10-09  160.500
# 2020-10-08  161.249
# 2020-10-07  156.750
#
# [1255 rows x 1 columns]

# %%
df[['open', 'close']]
# Out:
#                open    close
# Date
# 2025-10-06  221.000  220.900
# 2025-10-03  223.440  219.510
# 2025-10-02  221.010  222.410
# 2025-10-01  217.360  220.630
# 2025-09-30  222.030  219.570
# ...             ...      ...
# 2020-10-13  173.400  172.182
# 2020-10-12  167.497  172.146
# 2020-10-09  160.500  164.332
# 2020-10-08  161.249  159.528
# 2020-10-07  156.750  159.784
#
# [1255 rows x 2 columns]

# %%
df.iloc[:,0]
# Out:
# Date
# 2025-10-06    221.000
# 2025-10-03    223.440
# 2025-10-02    221.010
# 2025-10-01    217.360
# 2025-09-30    222.030
#                ...
# 2020-10-13    173.400
# 2020-10-12    167.497
# 2020-10-09    160.500
# 2020-10-08    161.249
# 2020-10-07    156.750
# Name: open, Length: 1255, dtype: float64

# %%
df.iloc[:,[0,3]]
# Out:
#                open    close
# Date
# 2025-10-06  221.000  220.900
# 2025-10-03  223.440  219.510
# 2025-10-02  221.010  222.410
# 2025-10-01  217.360  220.630
# 2025-09-30  222.030  219.570
# ...             ...      ...
# 2020-10-13  173.400  172.182
# 2020-10-12  167.497  172.146
# 2020-10-09  160.500  164.332
# 2020-10-08  161.249  159.528
# 2020-10-07  156.750  159.784
#
# [1255 rows x 2 columns]

# %%
df.iloc[:,3:5]
# Out:
#               close     volume
# Date
# 2025-10-06  220.900   42481401
# 2025-10-03  219.510   43639033
# 2025-10-02  222.410   41258586
# 2025-10-01  220.630   43933834
# 2025-09-30  219.570   48396369
# ...             ...        ...
# 2020-10-13  172.182  114893940
# 2020-10-12  172.146  167283960
# 2020-10-09  164.332   98157420
# 2020-10-08  159.528   63482280
# 2020-10-07  159.784   86188780
#
# [1255 rows x 2 columns]

# %%
df.iloc[:,-1]
# Out:
# Date
# 2025-10-06     42481401
# 2025-10-03     43639033
# 2025-10-02     41258586
# 2025-10-01     43933834
# 2025-09-30     48396369
#                 ...
# 2020-10-13    114893940
# 2020-10-12    167283960
# 2020-10-09     98157420
# 2020-10-08     63482280
# 2020-10-07     86188780
# Name: volume, Length: 1255, dtype: int64

# %%
df.iloc[:,[-1]]
# Out:
#                volume
# Date
# 2025-10-06   42481401
# 2025-10-03   43639033
# 2025-10-02   41258586
# 2025-10-01   43933834
# 2025-09-30   48396369
# ...               ...
# 2020-10-13  114893940
# 2020-10-12  167283960
# 2020-10-09   98157420
# 2020-10-08   63482280
# 2020-10-07   86188780
#
# [1255 rows x 1 columns]

# %%
df.iloc[:,-3:]
# Out:
#                 low    close     volume
# Date
# 2025-10-06  216.030  220.900   42481401
# 2025-10-03  219.340  219.510   43639033
# 2025-10-02  218.945  222.410   41258586
# 2025-10-01  216.610  220.630   43933834
# 2025-09-30  217.890  219.570   48396369
# ...             ...      ...        ...
# 2020-10-13  171.211  172.182  114893940
# 2020-10-12  166.978  172.146  167283960
# 2020-10-09  159.892  164.332   98157420
# 2020-10-08  158.749  159.528   63482280
# 2020-10-07  156.619  159.784   86188780
#
# [1255 rows x 3 columns]

# %%
df
# Out:
#                open     high      low    close     volume
# Date
# 2025-10-06  221.000  221.730  216.030  220.900   42481401
# 2025-10-03  223.440  224.200  219.340  219.510   43639033
# 2025-10-02  221.010  222.810  218.945  222.410   41258586
# 2025-10-01  217.360  222.150  216.610  220.630   43933834
# 2025-09-30  222.030  222.240  217.890  219.570   48396369
# ...             ...      ...      ...      ...        ...
# 2020-10-13  173.400  174.619  171.211  172.182  114893940
# 2020-10-12  167.497  174.812  166.978  172.146  167283960
# 2020-10-09  160.500  164.450  159.892  164.332   98157420
# 2020-10-08  161.249  161.665  158.749  159.528   63482280
# 2020-10-07  156.750  160.000  156.619  159.784   86188780
#
# [1255 rows x 5 columns]

# %%
df.iloc[0]
# Out:
# open           221.00
# high           221.73
# low            216.03
# close          220.90
# volume    42481401.00
# Name: 2025-10-06 00:00:00, dtype: float64

# %%
df.iloc[:3]
# Out:
#               open    high      low   close    volume
# Date
# 2025-10-06  221.00  221.73  216.030  220.90  42481401
# 2025-10-03  223.44  224.20  219.340  219.51  43639033
# 2025-10-02  221.01  222.81  218.945  222.41  41258586

# %%
df.loc['2021-01-04']
# Out:
# open      1.635000e+02
# high      1.636000e+02
# low       1.572010e+02
# close     1.593320e+02
# volume    8.822898e+07
# Name: 2021-01-04 00:00:00, dtype: float64

# %%
df.sort_index().loc['2021-01-04': '2021-01-07']
# Out:
#                open     high      low    close    volume
# Date
# 2021-01-04  163.500  163.600  157.201  159.332  88228980
# 2021-01-05  158.300  161.169  158.253  160.926  53110960
# 2021-01-06  157.324  159.875  156.558  156.919  87896300
# 2021-01-07  157.850  160.427  157.750  158.108  70290900
